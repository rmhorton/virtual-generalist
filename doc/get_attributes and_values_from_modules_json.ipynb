# %%
import re
import os
import json
from pathlib import Path
# import codecs

# %%
SYNTHEA_DIR = "/Volumes/data/synthea/"
MODULE_DIR = SYNTHEA_DIR + "build/resources/main/modules/"
LOOKUP_TABLE_DIR = MODULE_DIR + "lookup_tables"

# %% [markdown]
# # Which modules use which attributes?
# __NOTE__: You should probably use the gradle script `./gradlew attributes` instead; that is how `attributes.json` was generated.

# %%
# https://stackoverflow.com/questions/14962485/finding-a-key-recursively-in-a-dictionary

def get_recursively(search_dict, field):
    """
    Takes a dict with nested lists and dicts,
    and searches all dicts for a key of the field
    provided.
    """
    fields_found = []

    for key, value in search_dict.items():

        if key == field:
            fields_found.append(value)

        elif isinstance(value, dict):
            results = get_recursively(value, field)
            for result in results:
                fields_found.append(result)

        elif isinstance(value, list):
            for item in value:
                if isinstance(item, dict):
                    more_results = get_recursively(item, field)
                    for another_result in more_results:
                        fields_found.append(another_result)

    return fields_found

# %%
module_files = [path.relative_to(MODULE_DIR) for path in Path(MODULE_DIR).rglob('*.json')]
attribute_module = {}
for mf in module_files:
    with open(MODULE_DIR/mf, encoding='utf-8') as fh:
        data = json.load(fh)
        for k in ['attribute', 'assign_to_attribute']:
            attribute_list = set(get_recursively(data, k))
            for a in attribute_list:
                if a not in attribute_module:
                    attribute_module[a] = []
                attribute_module[a].append(str(mf))

# %%
attribute_module
# Out:
# t_cancer/surgery_therapy_breast.json',
#   'breast_cancer/tnm_diagnosis.json'],
#  'breast_cancer_aromatase_inhibitors': ['breast_cancer.json',
#   'breast_cancer/hormonetherapy_breast.json'],
#  'breast_cancer_chemoCount': ['breast_cancer/chemotherapy_breast.json'],
#  'breast_cancer_condition': ['breast_cancer.json',
#   'pickle_pica.json',
#   'covid19/determine_risk.json',
#   'covid19/medications.json'],
#  'breast_cancer_init_followup_counter': ['breast_cancer.json'],
#  'breast_cancer_neoCount': ['breast_cancer.json'],
#  'breast_cancer_neoMed': ['breast_cancer.json'],
#  'breast_cancer_survival': ['breast_cancer.json'],
#  'breast_cancer_tamoxifen': ['breast_cancer.json',
#   'breast_cancer/hormonetherapy_breast.json'],
#  'breast_cancer_treat_count': ['breast_cancer/surgery_therapy_breast.json'],
#  'breast_cancer_triple_negative': ['breast_cancer.json',
#   'breast_cancer/hormone_diagnosis.json',
#   'breast_cancer/surgery_therapy_breast.json'],
#  'breast_cancer_years_after_treatment': ['breast_cancer.json'],
#  'broken_bone': ['injuries.json'],
#  'bronchitis_careplan': ['bronchitis.json'],
#  'burn_injury': ['injuries.json'],
#  'chemoMed': ['breast_cancer/chemotherapy_breast.json'],
#  'chemotherapy1': ['lung_cancer.json', 'veteran_lung_cancer.json'],
#  'chemotherapy2': ['lung_cancer.json', 'veteran_lung_cancer.json'],
#  'chf': ['congestive_heart_failure.json',
#   'hypertension.json',
#   'pickle_pica.json',
#   'covid19/determine_risk.json'],
#  'chf_admissions': ['congestive_heart_failure.json'],
#  'chf_emergency_admissions': ['congestive_heart_failure.json'],
#  'chf_icu_admissions': ['congestive_heart_failure.json'],
#  'chf_inpatient_admissions': ['congestive_heart_failure.json'],
#  'chf_med_check': ['heart/chf_meds.json'],
#  'chf_med_step': ['heart/chf_meds.json',
#   'heart/chf_meds_hfmef.json',
#   'heart/chf_meds_hfref_nyha2.json',
#   'heart/chf_meds_hfref_nyha3.json',
#   'heart/chf_meds_hfref_nyha4.json'],
#  'chf_stage_d': ['congestive_heart_failure.json'],
#  'chf_type': ['congestive_heart_failure.json',
#   'heart/chf_meds.json',
#   'heart/chf_nyha_panel.json'],
#  'chronic_low_back_pain': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'chronic_low_back_pain_only': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'chronic_low_back_pain_with_fibromyalgia': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'chronic_neck_and_low_back_pain': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'chronic_neck_pain': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'chronic_neck_pain_only': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'ckd': ['dialysis.json',
#   'hypertension.json',
#   'metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json',
#   'covid19/admission.json',
#   'covid19/measurements_daily.json',
#   'covid19/medications.json',
#   'covid19/treat_blood_clot.json',
#   'heart/chf_meds_hfmef.json',
#   'heart/chf_meds_hfref_nyha2.json',
#   'heart/chf_meds_hfref_nyha3.json',
#   'heart/chf_meds_hfref_nyha4.json'],
#  'colorectal_adenoma': ['colorectal_cancer.json'],
#  'colorectal_cancer': ['colorectal_cancer.json'],
#  'colorectal_cancer_stage': ['colorectal_cancer.json',
#   'pickle_pica.json',
#   'covid19/determine_risk.json',
#   'covid19/medications.json'],
#  'concussion_injury': ['injuries.json'],
#  'contraceptive': ['contraceptives.json',
#   'contraceptives/clear_contraceptive.json',
#   'contraceptives/implant_contraceptive.json',
#   'contraceptives/injectable_contraceptive.json',
#   'contraceptives/intrauterine_device.json',
#   'contraceptives/oral_contraceptive.json',
#   'contraceptives/patch_contraceptive.json',
#   'contraceptives/ring_contraceptive.json'],
#  'contraceptive_type': ['contraceptive_maintenance.json',
#   'contraceptives.json',
#   'female_reproduction.json',
#   'contraceptives/clear_contraceptive.json',
#   'contraceptives/female_sterilization.json',
#   'contraceptives/implant_contraceptive.json',
#   'contraceptives/injectable_contraceptive.json',
#   'contraceptives/intrauterine_device.json',
#   'contraceptives/oral_contraceptive.json',
#   'contraceptives/patch_contraceptive.json',
#   'contraceptives/ring_contraceptive.json'],
#  'copd_variant': ['copd.json',
#   'pickle_pica.json',
#   'covid19/admission.json',
#   'covid19/determine_risk.json'],
#  'coronary_heart_disease': ['hypertension.json',
#   'pickle_pica.json',
#   'covid19/determine_risk.json'],
#  'covid19': ['covid19/infection.json'],
#  'covid19_admission_days': ['covid19/admission.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_all_labs': ['covid19/admission.json'],
#  'covid19_bacterial_infection': ['covid19/admission.json',
#   'covid19/diagnose_bacterial_infection.json',
#   'covid19/diagnose_bacterial_infection.json'],
#  'covid19_c_reactive_protein': ['covid19/measurements_frequent.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_cardiac_troponin': ['covid19/measurements_frequent.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_careplan': ['covid19/infection.json'],
#  'covid19_clinical_trial': ['covid19/measurements_frequent.json',
#   'covid19/medications.json'],
#  'covid19_clinical_trial_duration': ['covid19/medications.json'],
#  'covid19_clot': ['covid19/diagnose_blood_clot.json'],
#  'covid19_creatine_kinase': ['covid19/measurements_frequent.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_ddimer': ['covid19/diagnose_blood_clot.json',
#   'covid19/measurements_frequent.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_death': ['covid19/admission.json',
#   'covid19/determine_risk.json',
#   'covid19/infection.json',
#   'covid19/outcomes.json'],
#  'covid19_diagnosed_clot': ['covid19/diagnose_blood_clot.json',
#   'covid19/treat_blood_clot.json'],
#  'covid19_extubation_recovery_days': ['covid19/admission.json'],
#  'covid19_ferritin': ['covid19/measurements_frequent.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_hospitalization_days': ['covid19/admission.json'],
#  'covid19_icu_days': ['covid19/admission.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_inr': ['covid19/measurements_frequent.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_interleukin6': ['covid19/measurements_frequent.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_lactate_dehydrogenase': ['covid19/measurements_frequent.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_laryngoscope': ['covid19/supplies_intubation.json'],
#  'covid19_lymphocytes': ['covid19/measurements_daily.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_pao2': ['covid19/measurements_daily.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_procalcitonin': ['covid19/measurements_frequent.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_pt': ['covid19/measurements_frequent.json',
#   'covid19/nonsurvivor_lab_values.json',
#   'covid19/survivor_lab_values.json'],
#  'covid19_risk': ['covid19/determine_risk.json', 'covid19/infection.json'],
#  'covid19_severity': ['covid19/determine_risk.json',
#   'covid19/infection.json',
#   'covid19/medications.json',
#   'covid19/symptoms.json'],
#  'covid19_ventilator': ['covid19/supplies_intubation.json'],
#  'cr_chemo_count': ['colorectal_cancer.json'],
#  'current_weight_length_percentile': ['wellness_encounters.json'],
#  'dermatitis': ['dermatitis.json'],
#  'diabetes': ['cystic_fibrosis.json',
#   'halitosis_v01.json',
#   'metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json',
#   'pickle_pica.json',
#   'covid19/determine_risk.json'],
#  'diabetes_amputation_necessary': ['metabolic_syndrome_care.json'],
#  'diabetes_severity': ['metabolic_syndrome_care.json'],
#  'diabetes_stage': ['metabolic_syndrome_care.json'],
#  'diabetic_eye_damage': ['metabolic_syndrome_disease.json'],
#  'diabetic_nerve_damage': ['metabolic_syndrome_disease.json'],
#  'dialysis_reason': ['metabolic_syndrome_care.json'],
#  'ecg_result': ['gallstones.json'],
#  'end_stage_renal_disease': ['metabolic_syndrome_care.json'],
#  'fatal_pregnancy_complication': ['pregnancy.json'],
#  'fibromyalgia': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'fibromyalgia_careplan': ['fibromyalgia.json'],
#  'fibromyalgia_prescription': ['fibromyalgia.json', 'fibromyalgia.json'],
#  'food_allergy': ['food_allergies.json', 'allergies/allergy_incidence.json'],
#  'food_allergy_careplan': ['food_allergies.json', 'food_allergies.json'],
#  'gout_careplan': ['gout.json', 'gout.json'],
#  'gout_nsaid': ['gout.json'],
#  'gunshot_wound': ['injuries.json'],
#  'history_nonfatal_ED_overdose': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'homeless': ['homelessness.json'],
#  'homelessness_category': ['homelessness.json',
#   'pickle_pica.json',
#   'covid19/determine_risk.json'],
#  'hyperglycemia': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_care.json'],
#  'hyperlipidemia': ['veteran_hyperlipidemia.json'],
#  'hypertension': ['hypertension.json',
#   'metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json',
#   'pickle_pica.json',
#   'covid19/determine_risk.json',
#   'covid19/medications.json'],
#  'hypertension_dx': ['hypertension.json', 'hypertension.json'],
#  'hypertension_medication': ['medications/hypertension_medication.json'],
#  'hypertension_medication_2': ['medications/hypertension_medication.json'],
#  'hypertension_medication_3': ['medications/hypertension_medication.json'],
#  'hypertension_medication_step': ['medications/hypertension_medication.json'],
#  'hypertension_severe': ['hypertension.json',
#   'medications/hypertension_medication.json'],
#  'hypertriglyceridemia': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_care.json'],
#  'hypothyroidism': ['hypothyroidism.json'],
#  'immunotherapy_counter': ['allergies/immunotherapy.json'],
#  'immunotherapy_status': ['allergies.json', 'allergies/immunotherapy.json'],
#  'infertile': ['female_reproduction.json',
#   'contraceptives/female_sterilization.json',
#   'contraceptives/male_sterilization.json'],
#  'injury_careplan': ['injuries.json'],
#  'inpatient-los': ['congestive_heart_failure.json'],
#  'instances_of_homelessness': ['homelessness.json'],
#  'joint_replacement': ['osteoarthritis.json',
#   'rheumatoid_arthritis.json',
#   'total_joint_replacement.json',
#   'total_joint_replacement/functional_status_assessments.json'],
#  'knee_injury': ['injuries.json'],
#  'laceration_injury': ['injuries.json'],
#  'lung_cancer': ['lung_cancer.json',
#   'pickle_pica.json',
#   'veteran_lung_cancer.json',
#   'covid19/determine_risk.json',
#   'covid19/medications.json'],
#  'lung_cancer_nondiagnosis_counter': ['lung_cancer.json',
#   'veteran_lung_cancer.json'],
#  'lung_transplant': ['cystic_fibrosis.json'],
#  'lupus_careplan': ['lupus.json',
#   'pickle_pica.json',
#   'covid19/determine_risk.json'],
#  'lupus_corticosteroid': ['lupus.json'],
#  'mTBI': ['mTBI.json', 'veteran_ptsd.json'],
#  'macular_edema': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json'],
#  'mdd': ['veteran_mdd.json', 'veterans/veteran_suicide_probabilities.json'],
#  'mdd_psych': ['veteran_mdd.json'],
#  'mend_weekly_visit_count': ['weight_loss/mend_week.json'],
#  'mend_weeks': ['mend_program.json'],
#  'metabolic_syndrome': ['metabolic_syndrome_care.json'],
#  'microalbuminuria': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json',
#   'medications/hypertension_medication.json'],
#  'migraine': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'migraine_only': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'miscarriage': ['pregnancy.json'],
#  'nephropathy': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json'],
#  'neuropathy': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json'],
#  'no_treatment': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'non_low_risk_pregnancy': ['pregnancy.json'],
#  'nonopioid_Rx_1': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'nonopioid_Rx_2': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'nonproliferative_retinopathy': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json'],
#  'num_oud_treatment_visit': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'number_of_CBT': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'number_of_PT': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'number_of_children': ['pregnancy.json'],
#  'nyha_class': ['congestive_heart_failure.json',
#   'heart/chf_meds.json',
#   'heart/chf_nyha_panel.json'],
#  'obesity': ['metabolic_syndrome_care.json', 'metabolic_syndrome_care.json'],
#  'obesity_care_plan': ['mend_program.json'],
#  'on_buprenorphine': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'on_methadone': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'on_naltrexone': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'on_opioid_or_nonopioid': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'opioid_addiction': ['veteran_substance_abuse_conditions.json',
#   'veteran_substance_abuse_treatment.json',
#   'veterans/veteran_suicide_probabilities.json'],
#  'opioid_addiction_careplan': ['opioid_addiction.json',
#   'opioid_addiction.json'],
#  'opioid_prescription': ['fibromyalgia.json',
#   'fibromyalgia.json',
#   'opioid_addiction.json',
#   'opioid_addiction.json',
#   'medications/moderate_opioid_pain_reliever.json',
#   'medications/moderate_opioid_pain_reliever.json',
#   'medications/strong_opioid_pain_reliever.json',
#   'medications/strong_opioid_pain_reliever.json'],
#  'osteoarthritis': ['osteoarthritis.json'],
#  'osteoporosis': ['injuries.json', 'osteoporosis.json'],
#  'otc_antihistamine': ['medications/otc_antihistamine.json',
#   'medications/otc_antihistamine.json'],
#  'otc_pain_reliever': ['ear_infections.json',
#   'injuries.json',
#   'medications/otc_pain_reliever.json',
#   'medications/otc_pain_reliever.json'],
#  'outgrew_food_allergies': ['food_allergies.json',
#   'allergies/outgrow_food_allergies.json'],
#  'pharmaco': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'pharmaco_and_psychosocial': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'pickle_pica_risk': ['pickle_pica.json'],
#  'pickle_pica_severity': ['pickle_pica.json'],
#  'prediabetes': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json'],
#  'pregnancy_careplan': ['pregnancy.json'],
#  'pregnancy_complication': ['pregnancy.json', 'pregnancy.json'],
#  'pregnant': ['contraceptive_maintenance.json',
#   'contraceptives.json',
#   'female_reproduction.json',
#   'hypertension.json',
#   'pregnancy.json',
#   'anemia/anemia_sub.json',
#   'contraceptives/implant_contraceptive.json',
#   'contraceptives/injectable_contraceptive.json',
#   'contraceptives/intrauterine_device.json',
#   'contraceptives/oral_contraceptive.json',
#   'contraceptives/patch_contraceptive.json',
#   'contraceptives/ring_contraceptive.json',
#   'covid19/medications.json'],
#  'probability_of_fall_injury': ['injuries.json'],
#  'probability_of_lung_cancer': ['lung_cancer.json',
#   'veteran_lung_cancer.json',
#   'lung_cancer/lung_cancer_probabilities.json'],
#  'probability_of_lung_cancer_treatment': ['lung_cancer.json',
#   'veteran_lung_cancer.json'],
#  'probability_of_no_lung_cancer': ['lung_cancer.json',
#   'veteran_lung_cancer.json'],
#  'probability_of_no_lung_cancer_treatment': ['lung_cancer.json',
#   'veteran_lung_cancer.json'],
#  'probability_of_no_suicide': ['veteran_self_harm.json'],
#  'probability_of_suicide': ['veteran_self_harm.json',
#   'veterans/veteran_suicide_probabilities.json'],
#  'proliferative_retinopathy': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json'],
#  'prostate_cancer': ['veteran_prostate_cancer.json',
#   'veteran_prostate_cancer.json'],
#  'proteinuria': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json',
#   'medications/hypertension_medication.json'],
#  'psychosocial': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'ptsd': ['opioid_addiction.json',
#   'veteran_ptsd.json',
#   'veterans/veteran_suicide_probabilities.json'],
#  'ptsd_careplan': ['veteran_ptsd.json', 'veteran_ptsd.json'],
#  'quit smoking age': ['wellness_encounters.json',
#   'lung_cancer/lung_cancer_probabilities.json'],
#  'ra_careplan': ['pickle_pica.json',
#   'rheumatoid_arthritis.json',
#   'covid19/determine_risk.json'],
#  'readmit_1_month': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'readmit_1_year': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'readmit_2_days': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'recurrent_colorectal_adenoma': ['colorectal_cancer.json'],
#  'retinopathy': ['metabolic_syndrome_care.json',
#   'metabolic_syndrome_disease.json'],
#  'seizure': ['epilepsy.json'],
#  'seizure_meds': ['epilepsy.json'],
#  'sexual_orientation': ['homelessness.json'],
#  'sexually_active': ['female_reproduction.json', 'sexual_activity.json'],
#  'smoker': ['asthma.json',
#   'bronchitis.json',
#   'colorectal_cancer.json',
#   'congestive_heart_failure.json',
#   'copd.json',
#   'pickle_pica.json',
#   'veteran_lung_cancer.json',
#   'wellness_encounters.json',
#   'contraceptives/oral_contraceptive.json',
#   'covid19/determine_risk.json',
#   'lung_cancer/lung_cancer_probabilities.json'],
#  'smoking': ['veteran_substance_abuse_conditions.json',
#   'veteran_substance_abuse_treatment.json'],
#  'smoking_medication': ['veteran_substance_abuse_treatment.json',
#   'veteran_substance_abuse_treatment.json'],
#  'spinal_injury': ['injuries.json'],
#  'sprain_injury': ['injuries.json'],
#  'ssri': ['veteran_mdd.json', 'veteran_mdd.json'],
#  'statin_initial': ['veteran_hyperlipidemia.json',
#   'veteran_hyperlipidemia.json'],
#  'statin_renewal': ['veteran_hyperlipidemia.json'],
#  'suicide': ['self_harm.json', 'veteran_self_harm.json'],
#  'suicide_attempt': ['self_harm.json', 'veteran_self_harm.json'],
#  'suicide_careplan': ['self_harm.json',
#   'self_harm.json',
#   'veteran_self_harm.json',
#   'veteran_self_harm.json'],
#  'suicide_risk': ['veteran_ptsd.json'],
#  'text': ['metabolic_syndrome_care.json'],
#  'therapy_referral': ['prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json',
#   'prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json'],
#  'uti': ['urinary_tract_infections.json'],
#  'veteran': ['metabolic_syndrome_disease.json',
#   'mTBI.json',
#   'osteoarthritis.json',
#   'veteran.json',
#   'veteran_hyperlipidemia.json',
#   'veteran_lung_cancer.json',
#   'veteran_mdd.json',
#   'veteran_prostate_cancer.json',
#   'veteran_ptsd.json',
#   'veteran_self_harm.json',
#   'veteran_substance_abuse_conditions.json',
#   'veterans/veteran_suicide_probabilities.json'],
#  'veteran_population_override': ['veteran.json'],
#  'visit_allergist': ['allergic_rhinitis.json',
#   'allergies.json',
#   'dermatitis.json',
#   'food_allergies.json'],
#  'watchful_waiting': ['veteran_prostate_cancer.json',
#   'veteran_prostate_cancer.json'],
#  'weight_loss_adherence': ['weight_loss/mend_week.json']}

# %% [markdown]
# # What are the possible vlaues for each attribute?

# %%
def get_attribute_values_recursively(search_dict):
    """
    Takes a dict with nested lists and dicts, searches all dicts and returns the value of the 'attribute' and 'value' fields if there is a field called 'attribute'
    """
    attribute_values = {} # key = attribute name, value = list (eventually set) of attribute values

    def record_attribute_value(attr, val):
        if attr not in attribute_values:
            attribute_values[attr] = set()
        # attribute_values[attr].append(val)
        if isinstance(val, set): # set
           attribute_values[attr].update(val)
        else:
           attribute_values[attr].add(val)

    if ('attribute' in search_dict) and ('value' in search_dict):
        record_attribute_value(search_dict['attribute'], search_dict['value'])
    
    for key, value in search_dict.items():

        if isinstance(value, dict):
            results = get_attribute_values_recursively(value)
            for a,v in results.items():
                record_attribute_value(a,v)

        if isinstance(value, list):
            for item in value:
                if isinstance(item, dict):
                    more_results = get_attribute_values_recursively(item)
                    for a,v in more_results.items():
                        record_attribute_value(a,v)

    return attribute_values

# %%
# mf = 'asthma.json'


attribute_values_list = []
for mf in module_files:
    # print(str(mf))
    with open(MODULE_DIR/mf, encoding='utf-8') as fh:
        data = json.load(fh)
        my_attribute_values = get_attribute_values_recursively(data)
        if len(my_attribute_values) > 0:
            attribute_values_list.append(my_attribute_values)

# %%
def aggregate_attribute_values(attr_val_list):
    attr_val_dict = {}
    for d in attr_val_list:
        for k,v in d.items():
            if k not in attr_val_dict:
                attr_val_dict[k] = set()
            attr_val_dict[k].update(v)
    return attr_val_dict

aggregate_attribute_values(attribute_values_list)
# Out:
# {'G155D Mutation': {True},
#  'Lung Cancer Type': {'NSCLC', 'SCLC'},
#  'RH_NEG': {True},
#  'SSRI': {'Vicodin'},
#  'alcoholism': {True},
#  'anemia_pregnancy': {0, 1},
#  'assessment_done': {'HOOS',
#   'KOOS',
#   'PROMIS-10',
#   'PROMIS-29',
#   'VR-12',
#   'VR-36'},
#  'asthma_type': {'childhood', 'lifelong'},
#  'atopic': {True},
#  'birth_type': {'induced', 'normal', 'premature'},
#  'blindness': {True},
#  'blood_pressure_controlled': {False, True},
#  'bmi_percentile': {95},
#  'breast_cancer_ER': {'ER-negative', 'ER-positive'},
#  'breast_cancer_HER2': {'HER2-negative', 'HER2-positive'},
#  'breast_cancer_Location': {'distant', 'local', 'regional'},
#  'breast_cancer_M': {'M0', 'M1'},
#  'breast_cancer_N': {'N0', 'N1', 'N2', 'N3'},
#  'breast_cancer_PR': {'PR-negative', 'PR-positive'},
#  'breast_cancer_T': {'T0', 'T1', 'T2', 'T3', 'T4'},
#  'breast_cancer_aromatase_inhibitors': {True},
#  'breast_cancer_chemoCount': {0, 7},
#  'breast_cancer_init_followup_counter': {0, 3},
#  'breast_cancer_neoCount': {0, 7},
#  'breast_cancer_survival': {'no', 'yes'},
#  'breast_cancer_tamoxifen': {True},
#  'breast_cancer_treat_count': {0, 7, 33},
#  'breast_cancer_triple_negative': {True},
#  'breast_cancer_years_after_treatment': {0, 5},
#  'chf_admissions': {0, 2, 4},
#  'chf_emergency_admissions': {0},
#  'chf_icu_admissions': {0},
#  'chf_inpatient_admissions': {0},
#  'chf_med_step': {1, 2, 3},
#  'chf_stage_d': {True},
#  'chf_type': {'HFmEF', 'HFpEF', 'HFrEF'},
#  'ckd': {0, 1, 2, 3, 4, 5},
#  'colorectal_cancer_stage': {1, 2, 3, 4},
#  'contraceptive_type': {'condom',
#   'implant',
#   'injectable',
#   'iud',
#   'none',
#   'patch',
#   'pill',
#   'ring',
#   'sterilization',
#   'withdrawal'},
#  'coronary_heart_disease': {True},
#  'covid19_admission_days': {0, 7, 10, 13, 16, 19, 22},
#  'covid19_all_labs': {False, True},
#  'covid19_clinical_trial': {'anakinra',
#   'aviptadil',
#   'baricitinib',
#   'cd24fc',
#   'chloroquine_phosphate',
#   'chloroquine_phosphate+azithromycin',
#   'cm4620',
#   'convalescent_plasma',
#   'hydroxychloroquine',
#   'hydroxychloroquine+azithromycin',
#   'lenzilumab',
#   'leronlimab',
#   'lopinavir_ritonavir',
#   'lopinavir_rotinavir',
#   'losartan',
#   'none',
#   'remdesivir',
#   'sirolimus',
#   'toclizumab',
#   'tranexamic_acid'},
#  'covid19_clinical_trial_duration': {0, 1, 2, 3, 5, 9, 10, 14, 15},
#  'covid19_ddimer': {0.5},
#  'covid19_death': {False, True},
#  'covid19_diagnosed_clot': {False, True},
#  'covid19_extubation_recovery_days': {0},
#  'covid19_ferritin': {2000},
#  'covid19_hospitalization_days': {0},
#  'covid19_icu_days': {0, 2},
#  'covid19_risk': {'high', 'low'},
#  'covid19_severity': {'critical', 'general', 'negative', 'severe'},
#  'cr_chemo_count': {0, 6},
#  'diabetes': {True},
#  'diabetes_amputation_necessary': {False, True},
#  'diabetes_severity': {0, 1, 2, 3, 4},
#  'diabetic_eye_damage': {0, 1, 2, 3},
#  'diabetic_nerve_damage': {0, 1, 2, 3},
#  'history_nonfatal_ED_overdose': {True},
#  'homeless': {False, True},
#  'homelessness_category': {'chronic', 'temporary'},
#  'hypertension': {False, True},
#  'hypertension_medication_step': {0, 1, 2, 3},
#  'hypertension_severe': {False, True},
#  'immunotherapy_counter': {0, 60},
#  'immunotherapy_status': {'given', 'not-given'},
#  'infertile': {True},
#  'inpatient-los': {0, 5},
#  'instances_of_homelessness': {4},
#  'joint_replacement': {'hip', 'knee'},
#  'lung_cancer': {True},
#  'lung_cancer_nondiagnosis_counter': {0, 36, 72, 108},
#  'lung_transplant': {'accepted', 'denied'},
#  'macular_edema': {True},
#  'mend_weekly_visit_count': {0, 2},
#  'mend_weeks': {0, 10},
#  'microalbuminuria': {True},
#  'nephropathy': {True},
#  'neuropathy': {True},
#  'no_treatment': {True},
#  'nonproliferative_retinopathy': {True},
#  'num_oud_treatment_visit': {5},
#  'number_of_CBT': {8},
#  'number_of_PT': {10},
#  'number_of_children': {0},
#  'nyha_class': {1, 2, 3, 4},
#  'opioid_addiction': {True},
#  'osteoporosis': {True},
#  'outgrew_food_allergies': {'false', 'true'},
#  'pharmaco': {True},
#  'pharmaco_and_psychosocial': {True},
#  'pickle_pica_risk': {'high', 'low'},
#  'pickle_pica_severity': {'critical', 'moderate', 'negative', 'severe'},
#  'prediabetes': {True},
#  'pregnant': {False, True},
#  'probability_of_lung_cancer': {0.002, 0.004, 0.026, 0.055, 0.185, 0.244},
#  'probability_of_suicide': {0.003072, 0.006, 0.0072, 0.0144},
#  'proliferative_retinopathy': {True},
#  'proteinuria': {True},
#  'psychosocial': {True},
#  'readmit_1_month': {True},
#  'readmit_1_year': {True},
#  'readmit_2_days': {True},
#  'retinopathy': {True},
#  'sexually_active': {False, True},
#  'smoker': {True},
#  'smoking': {True},
#  'ssri': {0},
#  'veteran': {0,
#   'WW2',
#   'Between_WW2_and_KW',
#   'Korean_War',
#   'Pre_WW2',
#   'Vietnam_War',
#   'Between_KW_and_VW',
#   'Late_Gulf_War',
#   'Between_VW_and_GW',
#   'Early_Gulf_War'},
#  'visit_allergist': {True},
#  'weight_loss_adherence': {True}}
